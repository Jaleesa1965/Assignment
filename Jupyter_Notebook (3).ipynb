# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# My Jupyter Notebook

# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio </h1>

# %% [markdown]
# **Jaleesa Russell**
# Data Scientist

# %% [markdown]
# _I am interested in data science because the future will be driven by the use of data and it would be imperative to understand and utilize data science tools._

# %% [markdown]
# <h3> The code in cell 5 is suppose to add the numbers </h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# -  Nice
# -  to
# -  meet
# -  you
#
# 1. Learning
# 2. is
# 3. fun
#
#
# ![Picture1.jpg](attachment:0306677d-9b54-4af1-a088-e340db45ae52.jpg)
